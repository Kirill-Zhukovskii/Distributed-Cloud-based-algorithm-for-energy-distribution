# %%
import matplotlib.pyplot as plt
import numpy as np
import cvxpy as cp
import copy

# %%
# Set seed for reproducibility
np.random.seed(42)

# === 1. Time Horizon ===
H = 24
hours = np.arange(H)
base_price = 0.15
amplitude = 0.10
noise = np.random.normal(0, 0.01, size=H)

# Symmetric price
prices = base_price + amplitude * (
    np.sin((hours - 8) / 24 * 2 * np.pi) + np.sin((hours - 18) / 24 * 2 * np.pi)
) + noise
prices = np.clip(prices, 0.05, None)

# Add asymmetric buy/sell prices
margin = 0.05
c = prices + margin
p = prices - margin
p = np.clip(p, 0.01, None)  # Prevent negative prices


# === 3. Generate Renewable Energy ===
pv_gen = np.maximum(0, 5 * np.sin((hours - 6) * np.pi / 12))  # PV peaks at noon
wt_gen = 2 + np.random.rand(H) * 2  # Wind is random but consistent
q = (pv_gen + wt_gen)


# Plotting
fig, axs = plt.subplots(2, 1, figsize=(10, 12.5))  # 1 row, 2 columns

# First subplot: Buy and Sell Prices
axs[0].plot(hours, c, label='Buy Price (€/kWh)')
axs[0].plot(hours, p, label='Sell Price (€/kWh)')
axs[0].plot(hours, prices, label='Base Market Price (€/kWh)', linestyle='--', alpha=0.7)
axs[0].set_title("Simulated 24-Hour Electricity Buy and Sell Prices")
axs[0].set_xlabel("Hour")
axs[0].set_ylabel("Price (€/kWh)")
axs[0].grid(axis='y')
axs[0].set_xticks(range(0, 24))
axs[0].legend()

# Second subplot: Renewable energy
axs[1].plot(np.arange(H), q)
axs[1].set_title("Renewable Energy")
axs[1].set_xlabel("Hour")
axs[1].set_ylabel("Energy (Wh)")
axs[1].grid(axis='y')
axs[1].set_xticks(range(0, 24))

plt.tight_layout()
plt.savefig("Decentralised environmental parameters", dpi=300)
plt.show()

# %%
# Constants
N = 5   # Number of agents
rho = 1.8 #1.8
gamma = 0.09

epsilon = 0.1
c1 = 5
eta = 0.9

# Random seeds for reproducibility
np.random.seed(42)

L_target = np.random.uniform(70, 90, size=N)
L_init = np.random.uniform(20, 60, size=N)

L_min = np.ones((N, H)) * 20
L_max = np.ones((N, H)) * 100

d_min = np.zeros((N, H))
d_max = np.ones((N, H)) * 10

f_min = np.zeros((N, H))
f_max = np.ones((N, H)) * 10

l_min = -np.ones((N, H)) * 10
l_max = np.ones((N, H)) * 10

m_min = np.zeros((N, H))
m_max = np.ones((N, H)) * 10

# Initial values
x = np.array([np.zeros(4*H) for _ in range(N)])  # d, f, l, m, L[1:]
lambdas = np.zeros(H)

x_prev = copy.deepcopy(x)
iteration = 0

# Collect data for plotting
d_history = np.array([np.zeros(H) for n in range(N)])
f_history = np.array([np.zeros(H) for n in range(N)])
l_history = np.array([np.zeros(H) for n in range(N)])
m_history = np.array([np.zeros(H) for n in range(N)])
L_history = np.array([np.zeros(H) for n in range(N)])

cost_terms = []
penalty_terms = []

H_n_T_x = np.zeros((N,H))
H_n_T_xi = np.zeros((N,H))
# ADMM loop
while True:
    iteration += 1
    
    final_cost = 0
    for n in range(N):
        # Variables
        constraints = []
        xi = cp.Variable(4*H)
        d = xi[:H]
        f = xi[H:2*H]
        l = xi[2*H:3*H]
        L = xi[3*H:]

        # Objective components
        net_cost = c1*cp.sum(c @ d / q - p @ f / q)
    
        charge_penalty = (L[-1] - L_target[n])**2
    
        h_n_T_x = -d + f + l
        admm_penalty = (rho / 2) *  cp.sum_squares(h_n_T_x  + cp.sum(H_n_T_x,axis=0) - H_n_T_x[n] - q - 1/rho * lambdas)

        admm_update = 4.5 *cp.sum_squares(xi - x_prev[n])

        objective = cp.Minimize(net_cost + charge_penalty + admm_penalty +  admm_update)

        # Constraints
        constraints += [
            L >= L_min[n],
            L <= L_max[n],
            d >= d_min[n],
            d <= d_max[n],
            f >= f_min[n],
            f <= f_max[n],
            l >= l_min[n],
            l <= l_max[n],
        ]
        
        constraints += [
            L[0] == L_init[n] + l[0]
        ]
        for h in range(1, H):
            constraints += [
                L[h] == L[h-1] + l[h],
                cp.abs(l[h-1] - l[h]) <= 1,
                cp.abs(d[h-1] - d[h]) <= 1,
                cp.abs(f[h-1] - f[h]) <= 1,
            ]

        # Solve
        prob = cp.Problem(objective, constraints)
        prob.solve(solver=cp.OSQP, warm_start=True)
        """
        print(f"######### Parameters for Agent: {n} ##########")
        print(f"Net cost: {net_cost.value}")
        print(f"Charge penalty: {charge_penalty.value}")
        print(f"Lambda penalty: {admm_penalty.value}")
        print(f"Update penalty: {admm_update.value}")
        print(f"Objective value: {objective.value}")
        print(f"############################################")
        print(f" ")
        """
        # Save values
        x[n] = copy.deepcopy(xi.value)
        H_n_T_xi[n] = copy.deepcopy(h_n_T_x.value)

        # Collect data for plotting
        d_history[n] = copy.deepcopy(d.value)
        f_history[n] = copy.deepcopy(f.value)
        l_history[n] = copy.deepcopy(l.value)
        L_history[n] = copy.deepcopy(L.value)

        final_cost += net_cost.value + charge_penalty.value
    
    H_n_T_x = copy.deepcopy(H_n_T_xi)
    
    lambdas -= gamma * rho * (np.sum(H_n_T_x, axis=0) - q)
    #gamma *=0.9
    print("--------------------------------------------")
    print(f"ITERATION: {iteration}, difference: {np.linalg.norm(x-x_prev)}, lambda {np.mean(np.sum(H_n_T_x, axis=0) - q)}")
    print("--------------------------------------------")
    print(f" ")
    
    if np.linalg.norm(x-x_prev) <= epsilon:
        break
    
    x_prev = copy.deepcopy(x)
    
print(final_cost)
# Out:
# --------------------------------------------
# ITERATION: 1, difference: 242.69147518054314, lambda -2.636985728044214
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 2, difference: 24.116227034755497, lambda 2.3323157004169417
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 3, difference: 15.742462495056728, lambda 2.4112919990580663
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 4, difference: 13.363717399140633, lambda 2.4335389562334573
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 5, difference: 12.004708758450805, lambda 2.2476765171542463
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 6, difference: 10.832524991160124, lambda 2.0715273996856567
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 7, difference: 9.914218481736047, lambda 1.8376314292874927
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 8, difference: 9.092407488139285, lambda 1.6874121398252846
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 9, difference: 8.407398782567611, lambda 1.5128271540708813
# --------------------------------------------
#
# --------------------------------------------
# ITERATION:
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 346, difference: 0.3070494001517291, lambda -0.00614012498553157
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 347, difference: 0.30703133578222813, lambda -0.006290056615732842
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 348, difference: 0.3070175912126654, lambda -0.006437731813874932
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 349, difference: 0.30700683886169405, lambda -0.00654072396731938
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 350, difference: 0.30700190188968685, lambda -0.0066181225031179585
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 351, difference: 0.30699905125152965, lambda -0.006673066982242663
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 352, difference: 0.30700136783339615, lambda -0.006690005930680791
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 353, difference: 0.3070020779916039, lambda -0.006684120380881213
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 354, difference: 0.3070076910433703, lambda -0.006650965565841623
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 355, difference: 0.30701440659795387, lambda -0.006592517099000679
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 356, difference: 0.3070207493138917, lambda -0.006508780271960187
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 357, difference: 0.30702840233524276, lambda -0.006404176495516704
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 358, difference: 0.3070362972294119, lambda -0.006277162750659963
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 359, difference: 0.30704485708748885, lambda -0.006130986449409829
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 360, difference: 0.30705367529697025, lambda -0.005957746269395252
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 361, difference: 0.3070621493857434, lambda -0.005757322580736264
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 362, difference: 0.3070654386414851, lambda -0.005550320703459732
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 363, difference: 0.3070699223477105, lambda -0.005329082795716034
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 364, difference: 0.3070759065270603, lambda -0.005108074399757856
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 365, difference: 0.3070779553505791, lambda -0.004864984256131947
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 366, difference: 0.3070812602904767, lambda -0.0046030498431751665
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 367, difference: 0.3070812845638337, lambda -0.004343734246307056
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 368, difference: 0.3070810851108076, lambda -0.004073251629350683
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 369, difference: 0.30707882977949463, lambda -0.0037984831816710676
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 370, difference: 0.30707743502319207, lambda -0.003521059333701467
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 371, difference: 0.3070798724835136, lambda -0.0032607440361843154
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 372, difference: 0.30707796667499454, lambda -0.002962754195892814
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 373, difference: 0.3070712600708918, lambda -0.002709696289947383
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 374, difference: 0.30706438710060435, lambda -0.0024278650531947
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 375, difference: 0.30705897691415124, lambda -0.0021592851580313766
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 376, difference: 0.30705071698346464, lambda -0.0018884793122219874
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 377, difference: 0.30704308609599823, lambda -0.001609050178520403
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 378, difference: 0.30703587579508507, lambda -0.0013200011983339384
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 379, difference: 0.3070292700037157, lambda -0.0010429944699890854
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 380, difference: 0.30702240743560383, lambda -0.0007762959607513683
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 381, difference: 0.3070151437317625, lambda -0.0005208848938179264
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 382, difference: 0.3070085193460083, lambda -0.00027691084029065244
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 383, difference: 0.30700239977760774, lambda -4.480887719935748e-05
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 384, difference: 0.30699626319551765, lambda 0.00017521147333306639
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 385, difference: 0.30699075086622374, lambda 0.00038257577243587065
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 386, difference: 0.30698526402256593, lambda 0.0005776903462525462
# --------------------------------------------
#
# --------------------------------------------
# ITERATION: 387, difference: 0.3069805826732991, lambda 0.0007596309584524766
# --------------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 101
#      99 # Solve
#     100 prob = cp.Problem(objective, constraints)
# --> 101 prob.solve(solver=cp.OSQP, warm_start=True)
#     102 """
#     103 print(f"######### Parameters for Agent: {n} ##########")
#     104 print(f"Net cost: {net_cost.value}")
#    (...)
#     110 print(f" ")
#     111 """
#     112 # Save values
#
# File ~\anaconda3\Lib\site-packages\cvxpy\problems\problem.py:503, in Problem.solve(self, *args, **kwargs)
#     501 else:
#     502     solve_func = Problem._solve
# --> 503 return solve_func(self, *args, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\cvxpy\problems\problem.py:1073, in Problem._solve(self, solver, warm_start, verbose, gp, qcp, requires_grad, enforce_dpp, ignore_dpp, canon_backend, **kwargs)
#    1070         self.unpack(chain.retrieve(soln))
#    1071         return self.value
# -> 1073 data, solving_chain, inverse_data = self.get_problem_data(
#    1074     solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, kwargs
#    1075 )
#    1077 if verbose:
#    1078     print(_NUM_SOLVER_STR)
#
# File ~\anaconda3\Lib\site-packages\cvxpy\problems\problem.py:696, in Problem.get_problem_data(self, solver, gp, enforce_dpp, ignore_dpp, verbose, canon_backend, solver_opts)
#     693     s.LOGGER.info(
#     694              'Compiling problem (target solver=%s).', solver_name)
#     695     s.LOGGER.info('Reduction chain: %s', reduction_chain_str)
# --> 696 data, inverse_data = solving_chain.apply(self, verbose)
#     697 safe_to_cache = (
#     698     isinstance(data, dict)
#     699     and s.PARAM_PROB in data
#     700     and not any(isinstance(reduction, EvalParams)
#     701                 for reduction in solving_chain.reductions)
#     702 )
#     703 self._compilation_time = time.time() - start
#
# File ~\anaconda3\Lib\site-packages\cvxpy\reductions\chain.py:76, in Chain.apply(self, problem, verbose)
#      74     if verbose:
#      75         s.LOGGER.info('Applying reduction %s', type(r).__name__)
# ---> 76     problem, inv = r.apply(problem)
#      77     inverse_data.append(inv)
#      78 return problem, inverse_data
#
# File ~\anaconda3\Lib\site-packages\cvxpy\reductions\qp2quad_form\qp_matrix_stuffing.py:258, in QpMatrixStuffing.apply(self, problem)
#     256 # Form the constraints
#     257 extractor = CoeffExtractor(inverse_data, self.canon_backend)
# --> 258 params_to_P, params_to_q, flattened_variable = self.stuffed_objective(
#     259     problem, extractor)
#     260 # Lower equality and inequality to Zero and NonNeg.
#     261 cons = []
#
# File ~\anaconda3\Lib\site-packages\cvxpy\reductions\qp2quad_form\qp_matrix_stuffing.py:243, in QpMatrixStuffing.stuffed_objective(self, problem, extractor)
#     240 def stuffed_objective(self, problem, extractor):
#     241     # extract to 0.5 * x.T * P * x + q.T * x + r
#     242     expr = problem.objective.expr.copy()
# --> 243     params_to_P, params_to_q = extractor.quad_form(expr)
#     244     # Handle 0.5 factor.
#     245     params_to_P = 2*params_to_P
#
# File ~\anaconda3\Lib\site-packages\cvxpy\utilities\coeff_extractor.py:222, in CoeffExtractor.quad_form(self, expr)
#     218 quad_forms = replace_quad_forms(root, {})
#     220 # Calculate affine parts and combine them with quadratic forms to get
#     221 # the coefficients.
# --> 222 coeffs, constant = self.extract_quadratic_coeffs(root.args[0],
#     223                                                  quad_forms)
#     224 # Restore expression.
#     225 restore_quad_forms(root.args[0], quad_forms)
#
# File ~\anaconda3\Lib\site-packages\cvxpy\utilities\coeff_extractor.py:141, in CoeffExtractor.extract_quadratic_coeffs(self, affine_expr, quad_forms)
#     139     P = P.value.tocoo()
#     140 else:
# --> 141     P = sp.coo_matrix(P.value)
#     143 # We multiply P by the parameter coefficients.
#     144 if var_size == 1:
#     145     # Single quad form in the expression, i.e., we multiply
#     146     # the full P matrix by the non-zero entries of c_part.
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_coo.py:176, in _coo_base.__init__(self, arg1, shape, dtype, copy)
#     174     self._shape = check_shape(arg1.shape)
#     175 else:
# --> 176     coo = arg1.tocoo()
#     177     self.row = coo.row
#     178     self.col = coo.col
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_compressed.py:1040, in _cs_matrix.tocoo(self, copy)
#    1037 _sparsetools.expandptr(major_dim, self.indptr, major_indices)
#    1038 row, col = self._swap((major_indices, minor_indices))
# -> 1040 return self._coo_container(
#    1041     (self.data, (row, col)), self.shape, copy=copy,
#    1042     dtype=self.dtype
#    1043 )
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_coo.py:166, in _coo_base.__init__(self, arg1, shape, dtype, copy)
#     164         self.row = np.array(row, copy=copy, dtype=idx_dtype)
#     165         self.col = np.array(col, copy=copy, dtype=idx_dtype)
# --> 166         self.data = getdata(obj, copy=copy, dtype=dtype)
#     167         self.has_canonical_format = False
#     168 else:
#
# File ~\anaconda3\Lib\site-packages\scipy\sparse\_sputils.py:140, in getdata(obj, dtype, copy)
#     135 def getdata(obj, dtype=None, copy=False) -> np.ndarray:
#     136     """
#     137     This is a wrapper of `np.array(obj, dtype=dtype, copy=copy)`
#     138     that will generate a warning if the result is an object array.
#     139     """
# --> 140     data = np.array(obj, dtype=dtype, copy=copy)
#     141     # Defer to getdtype for checking that the dtype is OK.
#     142     # This is called for the validation only; we don't need the return value.
#     143     getdtype(data.dtype)
#
# KeyboardInterrupt:

# %%
plt.plot(-np.sum(d_history,axis=0)+np.sum(f_history,axis=0)+np.sum(l_history,axis=0)-np.sum(m_history,axis=0))
plt.plot(q)

# %%
# Plotting
fig, axes = plt.subplots(4, 1, figsize=(10, 5*2.5), sharex=True)

for n in range(N):
    #axes[0].plot(np.full(H,L_target[n]))
    axes[0].plot(L_history[n], label =f'agent {n}')
    axes[0].grid(axis='y')
    axes[0].legend()
    axes[0].set_ylabel("Load, Wh*h")

for n in range(N):
    axes[1].plot(d_history[n])
    axes[1].grid(axis='y')
    axes[1].set_ylabel("Draw from external grid, Wh")

for n in range(N):
    axes[2].plot(f_history[n])
    axes[2].grid(axis='y')
    axes[2].set_ylabel("Feed to external grid, Wh")
    
for n in range(N):
    axes[3].plot(l_history[n])
    axes[3].grid(axis='y')
    axes[3].set_ylabel("Charging from local DC-grid, Wh")
    

axes[-1].set_xlabel('Time Horizon, hour')
plt.tight_layout()
plt.savefig("Decentralised framework v2", dpi=300)
plt.show()

# %%
c1 * np.sum(c @ np.sum(d_history,axis=0)/q - p @ np.sum(f_history,axis=0)/q) + (L_target - L_history[:,-1]).T@(L_target - L_history[:,-1])
# Out:
# 1000.1952638369352
